# %%
# !jupyter contrib nbextension install --user
# Out:
# [I 23:06:05 InstallContribNbextensionsApp] jupyter contrib nbextension install --user
# [I 23:06:05 InstallContribNbextensionsApp] Installing jupyter_contrib_nbextensions nbextension files to jupyter data directory
# [I 23:06:05 InstallContribNbextensionsApp] Installing /home/echo/anaconda3/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/addbefore -> addbefore
# [I 23:06:05 InstallContribNbextensionsApp] Making directory: /home/echo/.local/share/jupyter/nbextensions/addbefore/
# [I 23:06:05 InstallContribNbextensionsApp] Copying: /home/echo/anaconda3/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/addbefore/addbefore.yaml -> /home/echo/.local/share/jupyter/nbextensions/addbefore/addbefore.yaml
# [I 23:06:05 InstallContribNbextensionsApp] Copying: /home/echo/anaconda3/lib/python3.9/site-packages/jupyter_contrib_nbextensions/nbextensions/addbefore/icon.png -> /home/echo/.local/share/jupyter/nbextensions/addbefore/icon.png
# ...

# %%
# !jupyter nbextensions_configurator enable --user
# Out:
# Enabling: jupyter_nbextensions_configurator
# - Writing config: /home/echo/.jupyter
#     - Validating...
#       jupyter_nbextensions_configurator 0.4.1 OK
# Enabling notebook nbextension nbextensions_configurator/config_menu/main...
# Enabling tree nbextension nbextensions_configurator/tree_tab/main...
